# %% [markdown]
# # Mission1

# %% [markdown]
# ## 전주시 지도 GeoPandas로 시각화하기

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df = gpd.read_file('C:\\Users\\user\\Desktop\\공공빅데이터 청년인턴십\\개인 학습\\전북 전주시\\LSMD_CONT_LDREG_45110.shp', encoding='euckr')

# %%
df.head()
# Out:
#                    pnu      jibun bchk  sgg_oid col_adm_se  \
# 0  4511114200117130017  1713-17 대    1   548104      45110
# 1  4511310200109540005    954-5 대    1   548105      45110
# 2  4511312600101710043   171-43 도    1   548106      45110
# 3  4511310200109540001    954-1 도    1   548107      45110
# 4  4511310200109530009    953-9 대    1   548108      45110
#
#                                             geometry
# 0  POLYGON ((208595.940 257398.350, 208595.940 25...
# 1  POLYGON ((211692.838 257950.305, 211693.709 25...
# 2  POLYGON ((203476.049 264970.797, 203473.144 26...
# 3  POLYGON ((211681.780 257930.959, 211679.696 25...
# 4  POLYGON ((211698.226 257971.991, 211699.750 25...

# %%
ax = df.plot(color='white', edgecolor='k', figsize=(15,15))
ax.set_title('Jeonjusi', fontsize = 40)
ax.set_axis_off()

plt.plot()
# Out:
# []

# %% [markdown]
# #### cf. 전주시 shp 데이터 기준으로 출력

# %%
df2 = gpd.read_file('C:\\Users\\user\\Desktop\\공공빅데이터 청년인턴십\\개인 학습\\전북 전주시\\hang2.shp', encoding='utf-8')

# %%
df2.head()
# Out:
#   BASE_DATE ADM_DR_CD ADM_DR_NM OBJECTID  \
# 0  20200630   3501160      동서학동     2273
# 1  20200630   3501161      서서학동     2274
# 2  20200630   3501162     중화산1동     2275
# 3  20200630   3501163     중화산2동     2276
# 4  20200630   3501164      평화1동     2277
#
#                                             geometry
# 0  POLYGON ((215976.469 256722.688, 215998.375 25...
# 1  POLYGON ((213536.002 257062.645, 213602.031 25...
# 2  POLYGON ((212387.716 258027.946, 212394.490 25...
# 3  POLYGON ((210218.999 258718.854, 210228.346 25...
# 4  POLYGON ((212918.555 256120.354, 212913.306 25...

# %%
#대근 킴 한글폰트 설정 솔루션_그래프 그릴 때 깨짐현상 해결
from matplotlib import font_manager

for font in font_manager.fontManager.ttflist:
    if 'Malgun' in font.name:
        print(font.name, font.fname)
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)        
        
        
        
bx = df2.plot(column = 'ADM_DR_NM', legend = True, categorical=True, figsize=(10, 10))
bx.set_title('Jeonju', fontsize=40)
bx.set_axis_off()
# Out:
# Malgun Gothic C:\Windows\Fonts\malgun.ttf
# Malgun Gothic C:\WINDOWS\Fonts\malgun.ttf
# Malgun Gothic C:\WINDOWS\Fonts\malgunsl.ttf
# Malgun Gothic C:\WINDOWS\Fonts\malgunbd.ttf
# Malgun Gothic C:\Windows\Fonts\malgunsl.ttf
# Malgun Gothic C:\Windows\Fonts\malgunbd.ttf

# %% [markdown]
# #### cf. 읍면동 shp 데이터로 출력

# %% [markdown]
# # Mission2

# %% [markdown]
# ## 전국 음식점 데이터 업종(한식 중식 양식 등) 기준으로 나눠서 pie chart로 구현하기

# %% [markdown]
# ### cf. 전국 음식점 파일 read가 안되서 ㅠ 전주 음식점 데이터로 대체합니다..

# %%
import pandas as pd

# %%
a = pd.read_csv('C:\\Users\\user\\Desktop\\데이터\\전라북도 전주시_음식점 정보_20201229.csv', encoding = 'utf-8')

# %%
a.columns
# Out:
# Index(['식당ID', '식당명', '업종(메뉴)정보', '테이크아웃여부', '예약가능여부', '선결제여부', '식당 대표전화번호',
#        '도로명주소', '지번주소', '정규휴업일', '식당면적', '식당위도', '식당경도', '대표메뉴', '어워드_글로벌',
#        '어워드_로컬', '트립어드바이저 인기도', '씨트립 인기도', '네이버 인기도', 'RTI 인덱스', '온라인화 진행 여부',
#        '다국어메뉴판 제공 여부', '다국어 지원언어', '다국어메뉴판 주소', '수용태세 지수', '좌석수(입식)',
#        '좌석수(좌식)', '베리어프리여부', '반려동물출입가능여부', '주차가능여부', '식당근처랜드마크정보', '랜드마크위도',
#        '랜드마크경도', '식당 홈페이지', '등록일시', '식당명-로마자', '업종정보명-영어', '업종정보명-일본어',
#        '업종정보명-중국어(간체)', '도로명주소-영어', '도로명주소-일본어', '도로명주소-중국어(간체)', '지번주소-영어',
#        '지번주소-일본어', '지번주소-중국어(간체)', '영업시간정보', '휴식시간정보'],
#       dtype='object')

# %%
jj_res = a[['식당ID','식당명','업종(메뉴)정보','식당 대표전화번호','도로명주소','지번주소','식당위도','식당경도','대표메뉴']]

# %%
jj_ctg = jj_res['업종(메뉴)정보'].value_counts()

# %%
'''
[Daeguen K's code support]

jj_ctg = jj_res['업종(메뉴)정보'].value_counts()
res_ctg = jj_ctg.index

not_ctg = ['생선회', '김밥', '맥주', '족발', '피자', '차', '국밥']
only_ctg = res_ctg[~res_ctg.isin(not_ctg)]
only_ctg
'''
# Out:
# "\n[Daeguen K's code support]\n\njj_ctg = jj_res['업종(메뉴)정보'].value_counts()\nres_ctg = jj_ctg.index\n\nnot_ctg = ['생선회', '김밥', '맥주', '족발', '피자', '차', '국밥']\nonly_ctg = res_ctg[~res_ctg.isin(not_ctg)]\nonly_ctg\n"

# %%
res_ctg = jj_ctg.index
res_ctg
# Out:
# Index(['카페', '한식', '분식', '치킨', '술집', '베이커리', '음식점', '피자', '육류', '중식', '생선회',
#        '김밥', '맥주', '차', '국수', '국밥', '찌개,전골', '족발', '돼지고기', '양식', '떡볶이', '죽',
#        '샌드위치', '칼국수', '햄버거', '닭갈비', '포장마차', '감자탕', '만두', '일식', '이탈리아음식', '순대국',
#        '아이스크림', '곱창,막창,양', '냉면', '소고기구이', '샤브샤브', '해물', '닭요리', '곱창', '한정식',
#        '추어탕', '순대', '초밥', '베트남음식', '돈가스', '케이크전문', '백반', '도시락', '우동', '닭발',
#        '곰탕', '패밀리레스토랑', '뷔페', '쌈밥', '오리요리', '토스트', '파스타', '브런치', '낙지', '양꼬치',
#        '핫도그', '빙수', '와인', '한식뷔페', '주꾸미', '해장국', '호두과자', '라멘', '퓨전음식', '보쌈',
#        '닭강정', '설렁탕', '생선구이', '양갈비', '게요리', '찜닭', '아귀찜', '과일주스', '전', '장어',
#        '복어요리', '커리', '와플', '샐러드', '해물탕', '전복요리', '막국수', '오뎅', '매운탕', '백숙',
#        '사철,영양탕', '푸드코트', '아시아음식', '도너츠', '보리밥', '두부요리집', '태국음식', '삼계탕'],
#       dtype='object')

# %%
not_for_chil = ['카페','술집','차','맥주','케이크전문','도너츠','아이스크림','와인','과일주스']
only_ctg = res_ctg[~res_ctg.isin(not_for_chil)]
only_ctg
# Out:
# Index(['한식', '분식', '치킨', '베이커리', '음식점', '피자', '육류', '중식', '생선회', '김밥', '국수',
#        '국밥', '찌개,전골', '족발', '돼지고기', '양식', '떡볶이', '죽', '샌드위치', '칼국수', '햄버거',
#        '닭갈비', '포장마차', '감자탕', '만두', '일식', '이탈리아음식', '순대국', '곱창,막창,양', '냉면',
#        '소고기구이', '샤브샤브', '해물', '닭요리', '곱창', '한정식', '추어탕', '순대', '초밥', '베트남음식',
#        '돈가스', '백반', '도시락', '우동', '닭발', '곰탕', '패밀리레스토랑', '뷔페', '쌈밥', '오리요리',
#        '토스트', '파스타', '브런치', '낙지', '양꼬치', '핫도그', '빙수', '한식뷔페', '주꾸미', '해장국',
#        '호두과자', '라멘', '퓨전음식', '보쌈', '닭강정', '설렁탕', '생선구이', '양갈비', '게요리', '찜닭',
#        '아귀찜', '전', '장어', '복어요리', '커리', '와플', '샐러드', '해물탕', '전복요리', '막국수', '오뎅',
#        '매운탕', '백숙', '사철,영양탕', '푸드코트', '아시아음식', '보리밥', '두부요리집', '태국음식', '삼계탕'],
#       dtype='object')

# %% [markdown]
# ## **막히는 부분

# %%
kfood = ['한식','김밥','국수','국밥','찌개,전골','족발','돼지고기','죽','닭갈비','감자탕','순대국','곱창,막창,양','한정식','추어탕','백반','곰탕','쌈밥','낙지','한식뷔페','주꾸미','해장국','보쌈','설렁탕','생선구이','찜닭','아귀찜','전','해물탕','매운탕','백숙','사철,영양탕','보리밥','두부요리집','삼계탕']
bfood = ['분식','칼국수','만두','냉면','우동','라멘','오뎅']
mfood = ['치킨','육류','족발','돼지고기','소고기구이','양꼬치','양갈비']
wfood = ['피자','햄버거','패밀리레스토랑','파스타','브런치','와플','이탈리아음식']
#대강 분류를 해보았다.
#어려운점_1: 정확하게 음식을 분류하기에 기준이 모호(기술적<주관적 요소)
#어려운점_2: 한식(kfood)으로 설정된 only_k_f 리스트의 요소들을 모두 합치고 싶은데, 인덱스 해제하는 법을 잘 모르겠다.
# ㄴ 만약 인덱스 해제 후 음식 종류별로 count를 합산할 수만 있다면, 원 그래프는 그릴 수 있을 것 같다.

only_k_f = only_ctg[only_ctg.isin(kfood)]
only_b_f = only_ctg[only_ctg.isin(bfood)]
only_m_f = only_ctg[only_ctg.isin(mfood)]
only_w_f = only_ctg[only_ctg.isin(wfood)]
# Out:
# Index(['피자', '햄버거', '이탈리아음식', '패밀리레스토랑', '파스타', '브런치', '와플'], dtype='object')

# %%
kf_df=jj_res[jj_res['업종(메뉴)정보'].isin(only_k_f)]
bf_df=jj_res[jj_res['업종(메뉴)정보'].isin(only_b_f)]
mf_df=jj_res[jj_res['업종(메뉴)정보'].isin(only_m_f)]
wf_df=jj_res[jj_res['업종(메뉴)정보'].isin(only_w_f)]

# %%
kf_series=kf_df['업종(메뉴)정보'].value_counts()
bf_series=bf_df['업종(메뉴)정보'].value_counts()
mf_series=mf_df['업종(메뉴)정보'].value_counts()
wf_series=wf_df['업종(메뉴)정보'].value_counts()

kf_num = kf_series.sum()
bf_num = bf_series.sum()
mf_num = mf_series.sum()
wf_num = wf_series.sum()

# %% [markdown]
# ## Pie 차트 그리기

# %%
labels = ['kfood','bfood','m_food','w_food']
ratio = [kf_num, bf_num, mf_num, wf_num]
wedgeprops = {'width': 0.7}

plt.pie(ratio, labels=labels, autopct='%0.1d%%', wedgeprops=wedgeprops)
# Out:
# ([<matplotlib.patches.Wedge at 0x1edb5490c70>,
#   <matplotlib.patches.Wedge at 0x1edb54a06d0>,
#   <matplotlib.patches.Wedge at 0x1edb54a0fa0>,
#   <matplotlib.patches.Wedge at 0x1edb54b5970>],
#  [Text(-0.17805389388872134, 1.0854938096880444, 'kfood'),
#   Text(-0.7894025107577772, -0.7660572276333654, 'bfood'),
#   Text(0.30678465111999803, -1.0563537181442497, 'm_food'),
#   Text(1.0423579202011901, -0.35141139166772833, 'w_food')],
#  [Text(-0.09712030575748436, 0.592087532557115, '55%'),
#   Text(-0.43058318768606024, -0.41784939689092654, '14%'),
#   Text(0.16733708242908982, -0.5761929371695907, '20%'),
#   Text(0.5685588655642855, -0.19167894090966997, '10%')])

# %% [markdown]
# #### 완벽하게 분류할 수 없어서 가능한 곳 까지
